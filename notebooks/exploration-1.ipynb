# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
#######
from numpy import isnan
from pandas import read_csv
# %matplotlib inline

# %%
# !ls ../raw_data
# Out:
# 'LFB Incident data from 2009 - 2017.csv'
# 'LFB Incident data from 2018 onwards.csv'
# 'LFB Incident data from 2018 onwards.csv.xlsx'
# 'LFB Mobilisation data 2021 - 2024.csv'
# 'LFB Mobilisation data 2021 - 2024.xlsx'
# 'LFB Mobilisation data from 2015 - 2020.csv'
# 'LFB Mobilisation data from 2015 - 2020.xlsx'
# 'LFB Mobilisation data from January 2009 - 2014.csv'
# 'LFB Mobilisation data from January 2009 - 2014.xlsx'
#  Metadata.pdf
#  Metadata.xlsx
# 'Mobilisations Metadata.pdf'
# 'Mobilisations Metadata.xlsx'

# %% [markdown]
# # Incident 2009-2017

# %%
df_incident_2009_2017 = pd.read_csv("../raw_data/LFB Incident data from 2009 - 2017.csv", index_col='IncidentNumber', low_memory=False)
# Display the first few rows
df_incident_2009_2017.head()
# Out:
#                DateOfCall  CalYear TimeOfCall  HourOfCall    IncidentGroup  \
# IncidentNumber
# 235138081.00    01-Jan-09     2009   00:00:37           0  Special Service
# 1091.00         01-Jan-09     2009   00:00:46           0  Special Service
# 2091.00         01-Jan-09     2009   00:03:00           0             Fire
# 3091.00         01-Jan-09     2009   00:04:27           0             Fire
# 5091.00         01-Jan-09     2009   00:05:39           0             Fire
#
#                StopCodeDescription     SpecialServiceType PropertyCategory  \
# IncidentNumber
# 235138081.00       Special Service                    RTC     Road Vehicle
# 1091.00            Special Service  Assist other agencies          Outdoor
# 2091.00             Secondary Fire                    NaN          Outdoor
# 3091.00             Secondary Fire                    NaN          Outdoor
# 5091.00             Secondary Fire                    NaN          Outdoor
#
# ...

# %%
df_incident_2009_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 988279 entries, 235138081.00 to 175197-31122017
# Data columns (total 38 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   DateOfCall                              988279 non-null  object
#  1   CalYear                                 988279 non-null  int64
#  2   TimeOfCall                              988279 non-null  object
#  3   HourOfCall                              988279 non-null  int64
#  4   IncidentGroup                           988279 non-null  object
#  5   StopCodeDescription                     988279 non-null  object
#  6   SpecialServiceType                      299101 non-null  object
#  7   PropertyCategory                        988279 non-null  object
#  8   PropertyType                            988279 non-null  object
#  9   AddressQualifier                        988279 non-null  object
# ...

# %%
df_incident_2009_2017['PropertyType'].nunique()
# Out:
# 290

# %%
start_time = time.time()  # Capture le temps au début
df_incident_2009_2017_NoIndex = pd.read_csv("../raw_data/LFB Incident data from 2009 - 2017.csv", low_memory=False)
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# Temps d'exécution : 3.670060873031616 secondes

# %%
df_incident_2009_2017_NoIndex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988279 entries, 0 to 988278
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   IncidentNumber                          988279 non-null  object
#  1   DateOfCall                              988279 non-null  object
#  2   CalYear                                 988279 non-null  int64
#  3   TimeOfCall                              988279 non-null  object
#  4   HourOfCall                              988279 non-null  int64
#  5   IncidentGroup                           988279 non-null  object
#  6   StopCodeDescription                     988279 non-null  object
#  7   SpecialServiceType                      299101 non-null  object
#  8   PropertyCategory                        988279 non-null  object
#  9   PropertyType                            988279 non-null  object
# ...

# %%
df_incident_2009_2017_NoIndex['Notional Cost (£)'].mean()
# Out:
# 358.11581041386086

# %%
# Afficher les valeurs uniques de la colonne IncidentNumber
print(df_incident_2009_2017_NoIndex['IncidentNumber'].unique())
# Out:
# ['235138081.00' '1091.00' '2091.00' ... '175194-31122017'
#  '175195-31122017' '175197-31122017']

# %%
print(df_incident_2009_2017_NoIndex['UPRN'].unique())
# Out:
# [           nan 1.00021492e+11 0.00000000e+00 ... 2.07118588e+08
#  2.02095947e+08 1.00251656e+10]

# %% [markdown]
# # Incident 2018-2024

# %%
df_incident_2018_2024 = pd.read_excel("../raw_data/LFB Incident data from 2018 onwards.csv.xlsx", index_col='IncidentNumber', engine='openpyxl')
# Display the first few rows
df_incident_2018_2024.head()
# Out:
#                 DateOfCall  CalYear TimeOfCall  HourOfCall    IncidentGroup  \
# IncidentNumber
# 000008-01012018 2018-01-01     2018   00:04:25           0      False Alarm
# 000009-01012018 2018-01-01     2018   00:04:30           0      False Alarm
# 000010-01012018 2018-01-01     2018   00:04:34           0             Fire
# 000011-01012018 2018-01-01     2018   00:04:58           0  Special Service
# 000014-01012018 2018-01-01     2018   00:07:47           0             Fire
#
#                 StopCodeDescription SpecialServiceType   PropertyCategory  \
# IncidentNumber
# 000008-01012018                 AFA                NaN    Non Residential
# 000009-01012018                 AFA                NaN    Non Residential
# 000010-01012018      Secondary Fire                NaN  Outdoor Structure
# 000011-01012018     Special Service                RTC       Road Vehicle
# 000014-01012018        Primary Fire                NaN       Road Vehicle
#
# ...

# %%
start_time = time.time()  # Capture le temps au début
df_incident_2018_2024_NoIndex = pd.read_excel("../raw_data/LFB Incident data from 2018 onwards.csv.xlsx", engine='openpyxl')
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# Temps d'exécution : 127.37154245376587 secondes

# %% [raw]
# df_incident_2018_2024_NoIndex.to_csv("../raw_data/LFB Incident data from 2018 onwards.csv", index=False)

# %%
start_time = time.time()  # Capture le temps au début
df_incident_2018_2024_NoIndex = pd.read_csv("../raw_data/LFB Incident data from 2018 onwards.csv")
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# Temps d'exécution : 2.036266565322876 secondes

# %%
df_incident_2018_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 747701 entries, 000008-01012018 to 126234-31072024
# Data columns (total 38 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   DateOfCall                              747701 non-null  datetime64[ns]
#  1   CalYear                                 747701 non-null  int64
#  2   TimeOfCall                              747701 non-null  object
#  3   HourOfCall                              747701 non-null  int64
#  4   IncidentGroup                           747695 non-null  object
#  5   StopCodeDescription                     747701 non-null  object
#  6   SpecialServiceType                      262834 non-null  object
#  7   PropertyCategory                        747695 non-null  object
#  8   PropertyType                            747695 non-null  object
#  9   AddressQualifier                        747700 non-null  object
# ...

# %% [markdown]
# # Mobilisation 2009-2014

# %%
df_mobilisation_2009_2014 = pd.read_excel("../raw_data/LFB Mobilisation data from January 2009 - 2014.xlsx", index_col='IncidentNumber', engine='openpyxl')
df_mobilisation_2009_2014.head()
# Out:
#                 CalYear  HourOfCall  ResourceMobilisationId Resource_Code  \
# IncidentNumber
# 235138081          2009           0                   38426          H271
# 235138081          2009           0                   38427          H212
# 2091               2009           0                   38429          A341
# 3091               2009           0                   38430          G232
# 5091               2009           0                   38432          A311
#
#                PerformanceReporting DateAndTimeMobilised   DateAndTimeMobile  \
# IncidentNumber
# 235138081                         1  2009-01-01 00:02:27                 NaT
# 235138081                         2  2009-01-01 00:02:27 2009-01-01 00:06:40
# 2091                              1  2009-01-01 00:04:09 2009-01-01 00:06:40
# 3091                              1  2009-01-01 00:04:57 2009-01-01 00:06:45
# 5091                              1  2009-01-01 00:06:04 2009-01-01 00:07:58
#
# ...

# %%
df_mobilisation_2009_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 901788 entries, 235138081 to 174346141
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CalYear                   901788 non-null  int64
#  1   HourOfCall                901788 non-null  int64
#  2   ResourceMobilisationId    901788 non-null  int64
#  3   Resource_Code             901788 non-null  object
#  4   PerformanceReporting      901788 non-null  object
#  5   DateAndTimeMobilised      901788 non-null  datetime64[ns]
#  6   DateAndTimeMobile         883728 non-null  datetime64[ns]
#  7   DateAndTimeArrived        901788 non-null  datetime64[ns]
#  8   TurnoutTimeSeconds        883636 non-null  float64
#  9   TravelTimeSeconds         883631 non-null  float64
#  10  AttendanceTimeSeconds     901788 non-null  int64
#  11  DateAndTimeLeft           856625 non-null  datetime64[ns]
# ...

# %%
start_time = time.time()  # Capture le temps au début
df_mobilisation_2009_2014_NoIndex = pd.read_excel("../raw_data/LFB Mobilisation data from January 2009 - 2014.xlsx", engine='openpyxl')
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# Temps d'exécution : 92.97841691970825 secondes

# %% [raw]
# # écriture en CSV
# df_mobilisation_2009_2014_NoIndex.to_csv("../raw_data/LFB Mobilisation data from January 2009 - 2014.csv", index=False)

# %%
start_time = time.time()  # Capture le temps au début
df_mobilisation_2009_2014_NoIndex = pd.read_csv("../raw_data/LFB Mobilisation data from January 2009 - 2014.csv")
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# Temps d'exécution : 1.945178508758545 secondes

# %%
df_mobilisation_2009_2014_NoIndex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901788 entries, 0 to 901787
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   IncidentNumber            901788 non-null  int64
#  1   CalYear                   901788 non-null  int64
#  2   HourOfCall                901788 non-null  int64
#  3   ResourceMobilisationId    901788 non-null  int64
#  4   Resource_Code             901788 non-null  object
#  5   PerformanceReporting      901788 non-null  object
#  6   DateAndTimeMobilised      901788 non-null  datetime64[ns]
#  7   DateAndTimeMobile         883728 non-null  datetime64[ns]
#  8   DateAndTimeArrived        901788 non-null  datetime64[ns]
#  9   TurnoutTimeSeconds        883636 non-null  float64
#  10  TravelTimeSeconds         883631 non-null  float64
#  11  AttendanceTimeSeconds     901788 non-null  int64
#  12  DateAndTimeLeft           856625 non-null  datetime64[ns]
# ...

# %%
diff = df_mobilisation_2009_2014_NoIndex['AttendanceTimeSeconds'] - df_mobilisation_2009_2014_NoIndex['TurnoutTimeSeconds'] \
- df_mobilisation_2009_2014_NoIndex['TravelTimeSeconds']

# %%
diff.unique()
# Out:
# array([nan,  0.])

# %%
df_mobilisation_2009_2014_NoIndex.iloc[0]
# Out:
# IncidentNumber                         235138081
# CalYear                                     2009
# HourOfCall                                     0
# ResourceMobilisationId                     38426
# Resource_Code                               H271
# PerformanceReporting                           1
# DateAndTimeMobilised         2009-01-01 00:02:27
# DateAndTimeMobile                            NaT
# DateAndTimeArrived           2009-01-01 00:07:46
# TurnoutTimeSeconds                           NaN
# TravelTimeSeconds                            NaN
# AttendanceTimeSeconds                        319
# DateAndTimeLeft              2009-01-01 00:16:46
# DateAndTimeReturned          2009-01-01 00:23:55
# DeployedFromStation_Code                     H27
# DeployedFromStation_Name               Battersea
# DeployedFromLocation                Home Station
# PumpOrder                                      1
# PlusCode_Code                            Initial
# ...

# %% [markdown]
# # Mobilisation 2015-2020

# %%
df_mobilisation_2015_2020 = pd.read_excel("../raw_data/LFB Mobilisation data from 2015 - 2020.xlsx", index_col='IncidentNumber', engine='openpyxl')
df_mobilisation_2015_2020.head()
# Out:
#                 CalYear  HourOfCall  ResourceMobilisationId Resource_Code  \
# IncidentNumber
# 1151               2015           0                 4436381          H262
# 1151               2015           0                 4436380          H261
# 4151               2015           0                 4436383          A352
# 8151               2015           0                 4436385          G251
# 10151              2015           0                 4436390          H291
#
#                PerformanceReporting DateAndTimeMobilised   DateAndTimeMobile  \
# IncidentNumber
# 1151                              1  2015-01-01 00:02:36 2015-01-01 00:03:55
# 1151                              2  2015-01-01 00:02:36 2015-01-01 00:03:50
# 4151                              1  2015-01-01 00:03:14 2015-01-01 00:03:58
# 8151                              1  2015-01-01 00:04:54 2015-01-01 00:06:10
# 10151                             1  2015-01-01 00:06:52 2015-01-01 00:11:01
#
# ...

# %%
start_time = time.time()  # Capture le temps au début
df_mobilisation_2015_2020_NoIndex = pd.read_excel("../raw_data/LFB Mobilisation data from 2015 - 2020.xlsx", engine='openpyxl')
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# Temps d'exécution : 93.2769501209259 secondes

# %% [raw]
# df_mobilisation_2015_2020_NoIndex.to_csv("../raw_data/LFB Mobilisation data from 2015 - 2020.csv", index=False)

# %%
start_time = time.time()  # Capture le temps au début
df_mobilisation_2015_2020_NoIndex = pd.read_csv("../raw_data/LFB Mobilisation data from 2015 - 2020.csv")
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# /tmp/ipykernel_7802/2313877142.py:2: DtypeWarning: Columns (0,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mobilisation_2015_2020_NoIndex = pd.read_csv("../raw_data/LFB Mobilisation data from 2015 - 2020.csv")
# Temps d'exécution : 1.7577743530273438 secondes

# %%
df_mobilisation_2015_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 883641 entries, 1151 to 164510-31122020
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CalYear                   883641 non-null  int64
#  1   HourOfCall                883641 non-null  int64
#  2   ResourceMobilisationId    883641 non-null  int64
#  3   Resource_Code             883641 non-null  object
#  4   PerformanceReporting      883641 non-null  object
#  5   DateAndTimeMobilised      883641 non-null  datetime64[ns]
#  6   DateAndTimeMobile         876365 non-null  datetime64[ns]
#  7   DateAndTimeArrived        883641 non-null  datetime64[ns]
#  8   TurnoutTimeSeconds        876339 non-null  float64
#  9   TravelTimeSeconds         876254 non-null  float64
#  10  AttendanceTimeSeconds     883641 non-null  int64
#  11  DateAndTimeLeft           882620 non-null  datetime64[ns]
# ...

# %% [markdown]
# # Mobilisation 2021-2024

# %%
df_mobilisation_2021_2024 = pd.read_excel("../raw_data/LFB Mobilisation data 2021 - 2024.xlsx", index_col='IncidentNumber', engine='openpyxl')
df_mobilisation_2021_2024.head()
# Out:
#                  CalYear  HourOfCall  ResourceMobilisationId Resource_Code  \
# IncidentNumber
# 000004-01012021     2021           0                 5769249          A321
# 000005-01012021     2021           0                 5769250          F351
# 000006-01012021     2021           0                 5769251          F412
# 000007-01012021     2021           0                 5769252          H331
# 000007-01012021     2021           0                 5769253          G351
#
#                 PerformanceReporting DateAndTimeMobilised   DateAndTimeMobile  \
# IncidentNumber
# 000004-01012021                    1  2021-01-01 00:06:47 2021-01-01 00:07:35
# 000005-01012021                    1  2021-01-01 00:07:47 2021-01-01 00:09:41
# 000006-01012021                    1  2021-01-01 00:08:21 2021-01-01 00:10:32
# 000007-01012021                    1  2021-01-01 00:12:23 2021-01-01 00:13:16
# 000007-01012021                    2  2021-01-01 00:12:23 2021-01-01 00:13:32
#
# ...

# %%
df_mobilisation_2021_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 638519 entries, 000004-01012021 to 125323-30072024
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CalYear                   638519 non-null  int64
#  1   HourOfCall                638519 non-null  int64
#  2   ResourceMobilisationId    638519 non-null  int64
#  3   Resource_Code             638519 non-null  object
#  4   PerformanceReporting      638519 non-null  object
#  5   DateAndTimeMobilised      638519 non-null  datetime64[ns]
#  6   DateAndTimeMobile         635724 non-null  datetime64[ns]
#  7   DateAndTimeArrived        638519 non-null  datetime64[ns]
#  8   TurnoutTimeSeconds        635706 non-null  float64
#  9   TravelTimeSeconds         635704 non-null  float64
#  10  AttendanceTimeSeconds     638519 non-null  int64
#  11  DateAndTimeLeft           638279 non-null  datetime64[ns]
# ...

# %%
start_time = time.time()  # Capture le temps au début
df_mobilisation_2021_2024_NoIndex = pd.read_excel("../raw_data/LFB Mobilisation data 2021 - 2024.xlsx", engine='openpyxl')
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# Temps d'exécution : 68.24601817131042 secondes

# %% [raw]
# df_mobilisation_2021_2024_NoIndex.to_csv("../raw_data/LFB Mobilisation data 2021 - 2024.csv", index=False)

# %%
start_time = time.time()  # Capture le temps au début
df_mobilisation_2015_2020_NoIndex = pd.read_csv("../raw_data/LFB Mobilisation data from 2015 - 2020.csv")
end_time = time.time()  # Capture le temps à la fin
execution_time = end_time - start_time
print(f"Temps d'exécution : {execution_time} secondes")
# Out:
# /tmp/ipykernel_7802/2313877142.py:2: DtypeWarning: Columns (0,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mobilisation_2015_2020_NoIndex = pd.read_csv("../raw_data/LFB Mobilisation data from 2015 - 2020.csv")
# Temps d'exécution : 1.8317952156066895 secondes

# %%
df_mobilisation_2021_2024_NoIndex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638519 entries, 0 to 638518
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   IncidentNumber            638519 non-null  object
#  1   CalYear                   638519 non-null  int64
#  2   HourOfCall                638519 non-null  int64
#  3   ResourceMobilisationId    638519 non-null  int64
#  4   Resource_Code             638519 non-null  object
#  5   PerformanceReporting      638519 non-null  object
#  6   DateAndTimeMobilised      638519 non-null  datetime64[ns]
#  7   DateAndTimeMobile         635724 non-null  datetime64[ns]
#  8   DateAndTimeArrived        638519 non-null  datetime64[ns]
#  9   TurnoutTimeSeconds        635706 non-null  float64
#  10  TravelTimeSeconds         635704 non-null  float64
#  11  AttendanceTimeSeconds     638519 non-null  int64
#  12  DateAndTimeLeft           638279 non-null  datetime64[ns]
# ...

# %% [raw]
# [i.weekday() for i in df_mobilisation_2021_2024['DateAndTimeMobilised']]
